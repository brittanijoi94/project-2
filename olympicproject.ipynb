# %%
import pandas as pd

# %%
DP_LIVE_02_df = pd.read_csv("DP_LIVE_02.csv")

# %%
DP_LIVE_02_df
# Out:
#      Unnamed: 0  Unnamed: 0.1 LOCATION  INDICATOR     SUBJECT  MEASURE  \
# 0             0             0      AUS  HEALTHEXP         TOT  USD_CAP
# 1             1             1      AUT  HEALTHEXP         TOT  USD_CAP
# 2             2             2      BEL  HEALTHEXP         TOT  USD_CAP
# 3             3             3      CAN  HEALTHEXP         TOT  USD_CAP
# 4             4             4      CZE  HEALTHEXP         TOT  USD_CAP
# ..          ...           ...      ...        ...         ...      ...
# 603         603           603      EST  HEALTHEXP   VOLUNTARY  USD_CAP
# 604         604           604      LTU  HEALTHEXP  COMPULSORY  USD_CAP
# 605         605           605      LTU  HEALTHEXP   VOLUNTARY  USD_CAP
# 606         606           606      SVN  HEALTHEXP  COMPULSORY  USD_CAP
# 607         607           607      SVN  HEALTHEXP   VOLUNTARY  USD_CAP
#
#     FREQUENCY  TIME     Value Flag Codes
# 0           A  2016  4624.966          D
# ...

# %%
DP_LIVE_02_2020_df=DP_LIVE_02_df[DP_LIVE_02 ['TIME']!=2020]
DP_LIVE_02_2020_df
# Out:
#      Unnamed: 0  Unnamed: 0.1 LOCATION  INDICATOR     SUBJECT  MEASURE  \
# 0             0             0      AUS  HEALTHEXP         TOT  USD_CAP
# 1             1             1      AUT  HEALTHEXP         TOT  USD_CAP
# 2             2             2      BEL  HEALTHEXP         TOT  USD_CAP
# 3             3             3      CAN  HEALTHEXP         TOT  USD_CAP
# 4             4             4      CZE  HEALTHEXP         TOT  USD_CAP
# ..          ...           ...      ...        ...         ...      ...
# 555         555           555      HRV  HEALTHEXP   VOLUNTARY  USD_CAP
# 556         556           556      CYP  HEALTHEXP  COMPULSORY  USD_CAP
# 557         557           557      CYP  HEALTHEXP   VOLUNTARY  USD_CAP
# 558         558           558      ROU  HEALTHEXP  COMPULSORY  USD_CAP
# 559         559           559      ROU  HEALTHEXP   VOLUNTARY  USD_CAP
#
#     FREQUENCY  TIME     Value Flag Codes
# 0           A  2016  4624.966          D
# ...

# %%
DP_LIVE_02_2019_df=DP_LIVE_02_2020_df[DP_LIVE_02 ['TIME']!=2019]
DP_LIVE_02_2019_df
# Out:
# <ipython-input-22-442ad64caa9a>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   DP_LIVE_02_2019_df=DP_LIVE_02_2020_df[DP_LIVE_02 ['TIME']!=2019]
#      Unnamed: 0  Unnamed: 0.1 LOCATION  INDICATOR     SUBJECT  MEASURE  \
# 0             0             0      AUS  HEALTHEXP         TOT  USD_CAP
# 1             1             1      AUT  HEALTHEXP         TOT  USD_CAP
# 2             2             2      BEL  HEALTHEXP         TOT  USD_CAP
# 3             3             3      CAN  HEALTHEXP         TOT  USD_CAP
# 4             4             4      CZE  HEALTHEXP         TOT  USD_CAP
# ..          ...           ...      ...        ...         ...      ...
# 427         427           427      CYP  HEALTHEXP   VOLUNTARY  USD_CAP
# 428         428           428      MLT  HEALTHEXP  COMPULSORY  USD_CAP
# 429         429           429      MLT  HEALTHEXP   VOLUNTARY  USD_CAP
# 430         430           430      ROU  HEALTHEXP  COMPULSORY  USD_CAP
# ...

# %%
DP_LIVE_02_2017_df=DP_LIVE_02_2019_df[DP_LIVE_02 ['TIME']!=2017]
DP_LIVE_02_2017_df
# Out:
# <ipython-input-23-7be65c24dec6>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   DP_LIVE_02_2017_df=DP_LIVE_02_2019_df[DP_LIVE_02 ['TIME']!=2017]
#      Unnamed: 0  Unnamed: 0.1 LOCATION  INDICATOR     SUBJECT  MEASURE  \
# 0             0             0      AUS  HEALTHEXP         TOT  USD_CAP
# 1             1             1      AUT  HEALTHEXP         TOT  USD_CAP
# 2             2             2      BEL  HEALTHEXP         TOT  USD_CAP
# 3             3             3      CAN  HEALTHEXP         TOT  USD_CAP
# 4             4             4      CZE  HEALTHEXP         TOT  USD_CAP
# ..          ...           ...      ...        ...         ...      ...
# 427         427           427      CYP  HEALTHEXP   VOLUNTARY  USD_CAP
# 428         428           428      MLT  HEALTHEXP  COMPULSORY  USD_CAP
# 429         429           429      MLT  HEALTHEXP   VOLUNTARY  USD_CAP
# 430         430           430      ROU  HEALTHEXP  COMPULSORY  USD_CAP
# ...

# %%
DP_LIVE_02_2016_df=DP_LIVE_02_2017_df[DP_LIVE_02 ['TIME']!=2016]
DP_LIVE_02_2016_df
# Out:
# <ipython-input-24-cf7ddea79467>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   DP_LIVE_02_2016_df=DP_LIVE_02_2017_df[DP_LIVE_02 ['TIME']!=2016]
#      Unnamed: 0  Unnamed: 0.1 LOCATION  INDICATOR     SUBJECT  MEASURE  \
# 288         288           288      AUS  HEALTHEXP         TOT  USD_CAP
# 289         289           289      AUT  HEALTHEXP         TOT  USD_CAP
# 290         290           290      BEL  HEALTHEXP         TOT  USD_CAP
# 291         291           291      CAN  HEALTHEXP         TOT  USD_CAP
# 292         292           292      CZE  HEALTHEXP         TOT  USD_CAP
# ..          ...           ...      ...        ...         ...      ...
# 427         427           427      CYP  HEALTHEXP   VOLUNTARY  USD_CAP
# 428         428           428      MLT  HEALTHEXP  COMPULSORY  USD_CAP
# 429         429           429      MLT  HEALTHEXP   VOLUNTARY  USD_CAP
# 430         430           430      ROU  HEALTHEXP  COMPULSORY  USD_CAP
# ...

# %%
DP_LIVE_02_2016_df["TIME"].unique()
# Out:
# array([2018])

# %%
DP_LIVE_02_2016_df["LOCATION"].unique()
# Out:
# array(['AUS', 'AUT', 'BEL', 'CAN', 'CZE', 'DNK', 'FIN', 'FRA', 'DEU',
#        'GRC', 'HUN', 'ISL', 'IRL', 'ITA', 'JPN', 'KOR', 'LUX', 'MEX',
#        'NLD', 'NZL', 'NOR', 'POL', 'PRT', 'SVK', 'ESP', 'SWE', 'CHE',
#        'TUR', 'GBR', 'USA', 'CHL', 'EST', 'ISR', 'SVN', 'CHN', 'COL',
#        'IND', 'IDN', 'LVA', 'LTU', 'RUS', 'ZAF', 'CRI', 'BGR', 'HRV',
#        'CYP', 'MLT', 'ROU'], dtype=object)

# %%
COUNTRIES = ["AUS","CAN","FRA","IRL","MEX","NOR","BEL","FIN","JPN","KOR"]
DP_LIVE_02_countries_df=DP_LIVE_02_2016_df[DP_LIVE_02_df['LOCATION'].isin(COUNTRIES)]
DP_LIVE_02_countries_df
# Out:
# <ipython-input-30-d02eb59de148>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   DP_LIVE_02_countries_df=DP_LIVE_02_2016_df[DP_LIVE_02_df['LOCATION'].isin(COUNTRIES)]
#      Unnamed: 0  Unnamed: 0.1 LOCATION  INDICATOR     SUBJECT  MEASURE  \
# 288         288           288      AUS  HEALTHEXP         TOT  USD_CAP
# 290         290           290      BEL  HEALTHEXP         TOT  USD_CAP
# 291         291           291      CAN  HEALTHEXP         TOT  USD_CAP
# 294         294           294      FIN  HEALTHEXP         TOT  USD_CAP
# 295         295           295      FRA  HEALTHEXP         TOT  USD_CAP
# 300         300           300      IRL  HEALTHEXP         TOT  USD_CAP
# 302         302           302      JPN  HEALTHEXP         TOT  USD_CAP
# 303         303           303      KOR  HEALTHEXP         TOT  USD_CAP
# 305         305           305      MEX  HEALTHEXP         TOT  USD_CAP
# ...

# %%
DP_LIVE_02_subjects_df=DP_LIVE_02_countries_df[DP_LIVE_02 ['SUBJECT']!='COMPULSORY']
DP_LIVE_02_subjects_df
# Out:
# <ipython-input-31-4c6d2fdb1e94>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   DP_LIVE_02_subjects_df=DP_LIVE_02_countries_df[DP_LIVE_02 ['SUBJECT']!='COMPULSORY']
#      Unnamed: 0  Unnamed: 0.1 LOCATION  INDICATOR    SUBJECT  MEASURE  \
# 288         288           288      AUS  HEALTHEXP        TOT  USD_CAP
# 290         290           290      BEL  HEALTHEXP        TOT  USD_CAP
# 291         291           291      CAN  HEALTHEXP        TOT  USD_CAP
# 294         294           294      FIN  HEALTHEXP        TOT  USD_CAP
# 295         295           295      FRA  HEALTHEXP        TOT  USD_CAP
# 300         300           300      IRL  HEALTHEXP        TOT  USD_CAP
# 302         302           302      JPN  HEALTHEXP        TOT  USD_CAP
# 303         303           303      KOR  HEALTHEXP        TOT  USD_CAP
# 305         305           305      MEX  HEALTHEXP        TOT  USD_CAP
# 308         308           308      NOR  HEALTHEXP        TOT  USD_CAP
# ...

# %%
DP_LIVE_02_vol_df=DP_LIVE_02_subjects_df[DP_LIVE_02 ['SUBJECT']!='VOLUNTARY']
DP_LIVE_02_vol_df
# Out:
# <ipython-input-32-f32c12fdfcfe>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   DP_LIVE_02_vol_df=DP_LIVE_02_subjects_df[DP_LIVE_02 ['SUBJECT']!='VOLUNTARY']
#      Unnamed: 0  Unnamed: 0.1 LOCATION  INDICATOR SUBJECT  MEASURE FREQUENCY  \
# 288         288           288      AUS  HEALTHEXP     TOT  USD_CAP         A
# 290         290           290      BEL  HEALTHEXP     TOT  USD_CAP         A
# 291         291           291      CAN  HEALTHEXP     TOT  USD_CAP         A
# 294         294           294      FIN  HEALTHEXP     TOT  USD_CAP         A
# 295         295           295      FRA  HEALTHEXP     TOT  USD_CAP         A
# 300         300           300      IRL  HEALTHEXP     TOT  USD_CAP         A
# 302         302           302      JPN  HEALTHEXP     TOT  USD_CAP         A
# 303         303           303      KOR  HEALTHEXP     TOT  USD_CAP         A
# 305         305           305      MEX  HEALTHEXP     TOT  USD_CAP         A
# ...

# %%
DP_LIVE_02_vol_df.to_csv('DP_LIVE_02_vol_df.csv')
