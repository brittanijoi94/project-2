# %%
import pandas as pd

# %%
DP_LIVE_02 = pd.read_csv("DP_LIVE_02.csv")

# %%
DP_LIVE_02.head(10)
# Out:
#   LOCATION  INDICATOR SUBJECT  MEASURE FREQUENCY  TIME     Value Flag Codes
# 0      AUS  HEALTHEXP     TOT  USD_CAP         A  2016  4624.966          D
# 1      AUS  HEALTHEXP     TOT  USD_CAP         A  2017  4659.025          D
# 2      AUS  HEALTHEXP     TOT  USD_CAP         A  2018  4793.460          D
# 3      AUS  HEALTHEXP     TOT  USD_CAP         A  2019  4919.240          E
# 4      AUT  HEALTHEXP     TOT  USD_CAP         A  2016  5195.531        NaN
# 5      AUT  HEALTHEXP     TOT  USD_CAP         A  2017  5315.353        NaN
# 6      AUT  HEALTHEXP     TOT  USD_CAP         A  2018  5544.767        NaN
# 7      AUT  HEALTHEXP     TOT  USD_CAP         A  2019  5705.102        NaN
# 8      AUT  HEALTHEXP     TOT  USD_CAP         A  2020  5899.139          P
# 9      BEL  HEALTHEXP     TOT  USD_CAP         A  2016  5003.902        NaN

# %%
DP_LIVE_02_not_2020 = DP_LIVE_02[DP_LIVE_02['TIME']!=2020]
DP_LIVE_02_not_2020.head(100)
# Out:
#     LOCATION  INDICATOR SUBJECT  MEASURE FREQUENCY  TIME     Value Flag Codes
# 0        AUS  HEALTHEXP     TOT  USD_CAP         A  2016  4624.966          D
# 1        AUS  HEALTHEXP     TOT  USD_CAP         A  2017  4659.025          D
# 2        AUS  HEALTHEXP     TOT  USD_CAP         A  2018  4793.460          D
# 3        AUS  HEALTHEXP     TOT  USD_CAP         A  2019  4919.240          E
# 4        AUT  HEALTHEXP     TOT  USD_CAP         A  2016  5195.531        NaN
# ..       ...        ...     ...      ...       ...   ...       ...        ...
# 105      SVK  HEALTHEXP     TOT  USD_CAP         A  2019  2189.052        NaN
# 106      ESP  HEALTHEXP     TOT  USD_CAP         A  2016  3148.584        NaN
# 107      ESP  HEALTHEXP     TOT  USD_CAP         A  2017  3320.594        NaN
# 108      ESP  HEALTHEXP     TOT  USD_CAP         A  2018  3443.656        NaN
# 109      ESP  HEALTHEXP     TOT  USD_CAP         A  2019  3600.277          P
#
# [100 rows x 8 columns]

# %%
DP_LIVE_02_not_2020["TIME"].unique()
# Out:
# array([2016, 2017, 2018, 2019])

# %%
DP_LIVE_02_not_2020["LOCATION"].unique()
# Out:
# array(['AUS', 'AUT', 'BEL', 'CAN', 'CZE', 'DNK', 'FIN', 'FRA', 'DEU',
#        'GRC', 'HUN', 'ISL', 'IRL', 'ITA', 'JPN', 'KOR', 'LUX', 'MEX',
#        'NLD', 'NZL', 'NOR', 'POL', 'PRT', 'SVK', 'ESP', 'SWE', 'CHE',
#        'TUR', 'GBR', 'USA', 'CHL', 'EST', 'ISR', 'SVN', 'CHN', 'COL',
#        'IND', 'IDN', 'LVA', 'LTU', 'RUS', 'ZAF', 'CRI', 'BGR', 'HRV',
#        'CYP', 'MLT', 'ROU'], dtype=object)

# %%
COUNTRIES = ["AUS","CAN","FRA","IRL","MEX","NOR","BEL","FIN","JPN","KOR"]
DP_LIVE_02_not_2020[DP_LIVE_02_not_2020['LOCATION'].isin(COUNTRIES)]
# Out:
#     LOCATION  INDICATOR     SUBJECT  MEASURE FREQUENCY  TIME     Value  \
# 0        AUS  HEALTHEXP         TOT  USD_CAP         A  2016  4624.966
# 1        AUS  HEALTHEXP         TOT  USD_CAP         A  2017  4659.025
# 2        AUS  HEALTHEXP         TOT  USD_CAP         A  2018  4793.460
# 3        AUS  HEALTHEXP         TOT  USD_CAP         A  2019  4919.240
# 9        BEL  HEALTHEXP         TOT  USD_CAP         A  2016  5003.902
# ..       ...        ...         ...      ...       ...   ...       ...
# 379      NOR  HEALTHEXP  COMPULSORY  USD_CAP         A  2019  5788.239
# 381      NOR  HEALTHEXP   VOLUNTARY  USD_CAP         A  2016   863.230
# 382      NOR  HEALTHEXP   VOLUNTARY  USD_CAP         A  2017   927.634
# 383      NOR  HEALTHEXP   VOLUNTARY  USD_CAP         A  2018   934.528
# 384      NOR  HEALTHEXP   VOLUNTARY  USD_CAP         A  2019   956.383
#
#     Flag Codes
# 0            D
# 1            D
# 2            D
# 3            E
# 9          NaN
# ..         ...
# ...
