# %%
import pandas as pd

# %%
olympics=('C')

# %%
olympics_df=pd.read_csv('Tokyo 2021 dataset (1) (1).csv')

# %%
olympics_df
# Out:
#     Rank                    Team/NOC  Gold Medal  Silver Medal  Bronze Medal  \
# 0      1    United States of America          39            41            33
# 1      2  People's Republic of China          38            32            18
# 2      3                       Japan          27            14            17
# 3      4               Great Britain          22            21            22
# 4      5                         ROC          20            28            23
# ..   ...                         ...         ...           ...           ...
# 88    86                       Ghana           0             0             1
# 89    86                     Grenada           0             0             1
# 90    86                      Kuwait           0             0             1
# 91    86         Republic of Moldova           0             0             1
# 92    86        Syrian Arab Republic           0             0             1
#
#     Total  Rank by Total NOCCode
# ...

# %%
olympics_df.rename({'Team/NOC' : 'Location'}, axis=1, inplace=True)
olympics_df
# Out:
#     Rank                    Location  Gold Medal  Silver Medal  Bronze Medal  \
# 0      1    United States of America          39            41            33
# 1      2  People's Republic of China          38            32            18
# 2      3                       Japan          27            14            17
# 3      4               Great Britain          22            21            22
# 4      5                         ROC          20            28            23
# ..   ...                         ...         ...           ...           ...
# 88    86                       Ghana           0             0             1
# 89    86                     Grenada           0             0             1
# 90    86                      Kuwait           0             0             1
# 91    86         Republic of Moldova           0             0             1
# 92    86        Syrian Arab Republic           0             0             1
#
#     Total  Rank by Total NOCCode
# ...

# %%
olympics_df.drop(['Rank', 'Total', 'Rank by Total', 'NOCCode'], axis=1, inplace=True)
olympics_df
# Out:
#                       Location  Gold Medal  Silver Medal  Bronze Medal
# 0     United States of America          39            41            33
# 1   People's Republic of China          38            32            18
# 2                        Japan          27            14            17
# 3                Great Britain          22            21            22
# 4                          ROC          20            28            23
# ..                         ...         ...           ...           ...
# 88                       Ghana           0             0             1
# 89                     Grenada           0             0             1
# 90                      Kuwait           0             0             1
# 91         Republic of Moldova           0             0             1
# 92        Syrian Arab Republic           0             0             1
#
# [93 rows x 4 columns]

# %%
olympics_10=olympics_df.loc[[2, 5, 7, 10, 15, 19, 28, 38, 83, 84]]
olympics_10
# Out:
#              Location  Gold Medal  Silver Medal  Bronze Medal
# 2               Japan          27            14            17
# 5           Australia          17             7            22
# 7              France          10            12            11
# 10             Canada           7             6            11
# 15  Republic of Korea           6             4            10
# 19             Norway           4             2             2
# 28            Belgium           3             1             3
# 38            Ireland           2             0             2
# 83             Mexico           0             0             4
# 84            Finland           0             0             2

# %%
olympics_10.to_csv('olympics_10_df.csv')
